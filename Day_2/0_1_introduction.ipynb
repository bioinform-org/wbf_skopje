# %% [markdown]
# # **Introduction to Python and notebooks**
#
# This notebook allows you to write and execute Python in your browser, with zero configuration required.
#
# For example, here is a <strong>code cell</strong> with a short Python script that computes a value, stores it in a variable and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
print(seconds_in_a_day)
# Out:
# 86400

# %% [markdown]
# The cell above was initialised by clicking the `+ Code` button on top of this page. This cell instead was initialised by clicking the `+ Text` button on top of this page. You can edit both text and code cells by double clicking on them.
#
# You can execute code cells by clicking the run icon ▶ on the left side of a code cell or by using the keyboard combination: `⬆ Shift + Enter`

# %% [markdown]
# ## **Concepts in Python**
#
# ### Variables
#
# In Python, variable names:
#
# * can include letters, digits, and underscores
# * cannot start with a digit
# * are case sensitive.
#
# This means that, for example:
#
# * `weight0` is a valid variable name, whereas `0weight` is not
# * `weight` and `Weight` are different variables

# %% [markdown]
# **Exercise 0.1.1**
#
# What values do the variables mass and age have after each of the following statements? Test your answer by executing the lines. To check what is their values, remember that you will need to use the `print()` function to check the values.

# %%
mass = 47.5
age = 122
mass = mass * 2.0
age = age - 20

# %% [markdown]
# **Exercise 0.1.2**
#
# Python allows you to assign multiple values to multiple variables in one line by separating the variables and values with commas. What does the following program print out?

# %%
first, second = 'Grace', 'Hopper'
third, fourth = second, first
print(third, fourth)
# Out:
# Hopper Grace

# %% [markdown]
# **Exercise 0.1.3**
#
# What are the data types of the following variables? How do you check it?

# %%
planet = 'Earth'
apples = 5
distance = 10.5

# %% [markdown]
# **Exercise 0.1.4**
#
# What type of value (integer, floating point number, or character string) would you use to represent each of the following? Try to come up with more than one good answer for each problem. For example, in # 1, when would counting days with a floating point variable make more sense than using an integer?
#
# 1. Number of days since the start of the year.
# 2. Time elapsed from the start of the year until now in days.
# 3. Serial number of a piece of lab equipment.
# 4. A lab specimen’s age.
# 5. Current population of a city.
# 6. Average population of a city over time

# %% [markdown]
# ## Other built-in functions
#
# * Use `max` to find the largest value of one or more values.
# * Use `min` to find the smallest.
#
# These functions **return** a value, which means that they produce a result.
#
# Actually, **every function produces a result**, but if the function doesn’t have a useful result to return, it usually returns the special value `None`. Chcek what happens in the next cell.

# %%
result = print('example')
print('result of print is', result )
# Out:
# example
# result of print is None

# %% [markdown]
# To see the result of a function with a returned value, we need to print it.

# %%
print(max(1, 2, 3))
print(min('a', 'A', '0'))
# Out:
# 3
# 0

# %% [markdown]
# **There are rules for using each function**
#
# * `max` and `min` must be given at least one argument
# * and they must be given things that can meaningfully be compared
#
# See what happens in the cell below

# %%
print(max(1, 'a'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3f049acf3762> in <cell line: 1>()
# ----> 1 print(max(1, 'a'))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# Don't worry! Errors are here to help us. We will give more details in the next set of slides.

# %% [markdown]
# ---

# %% [markdown]
# ## Lists
#
# Use `list_name.append` to add items to the end of a list.
# * `append` is a method of lists
#   * Like a function, but tied to a particular object.
# * Use `object_name.method_name` to call methods.
# * Use `help(list)` for a preview.
# * `extend` is similar to `append`, but it allows you to combine two lists.

# %%
primes = [2, 3, 5]
print('primes is initially:', primes)
primes.append(7)
print('primes has become:', primes)
teen_primes = [11, 13, 17, 19]
primes.extend(teen_primes)
print('primes has now become:', primes)
# Out:
# primes is initially: [2, 3, 5]
# primes has become: [2, 3, 5, 7]
# primes has now become: [2, 3, 5, 7, 11, 13, 17, 19]

# %% [markdown]
# * The empty list `[]` contains no values.
# * Lists may contain values of different types.
# * Indexing beyond the end of the collection is an error.

# %% [markdown]
# **Exercise 0.2.1**
# Fill in the blanks so that the program below produces the output shown.

# %%
values = ____
values.____(1)
values.____(3)
values.____(5)
print('first time:', values)
values = values[____]
print('second time:', values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-cff570c484ba> in <cell line: 1>()
# ----> 1 values = ____
#       2 values.____(1)
#       3 values.____(3)
#       4 values.____(5)
#       5 print('first time:', values)
#
# NameError: name '____' is not defined

# %% [markdown]
# **Exercise 0.2.2**
#
# What does the following program print?
#
# 1. How does Python interpret a negative index?
# 2. If a list or string has N elements, what is the most negative index that can safely be used with it, and what location does that index represent?
# 3. If `values` is a list, what does `del values[-1]` do?

# %%
element = 'helium'
print(element[-1])
# Out:
# m

# %% [markdown]
# **Exercise 0.2.3**
#
# What do these two programs print? In simple terms, explain the difference between sorted(letters) and letters.sort().

# %%
# Program A
letters = list('gold')
result = sorted(letters)
print('letters is', letters, 'and result is', result)

# Program B
letters = list('gold')
result = letters.sort()
print('letters is', letters, 'and result is', result)
# Out:
# letters is ['g', 'o', 'l', 'd'] and result is ['d', 'g', 'l', 'o']
# letters is ['d', 'g', 'l', 'o'] and result is None

# %% [markdown]
# * Notice the comments used above

# %% [markdown]
# ## For loops

# %% [markdown]
# **Exercise 0.2.4**
#
# Create a table showing the numbers of the lines that are executed when this program runs, and the values of the variables after each line is executed.

# %%
total = 0
for char in "tin":
    total = total + 1

# %% [markdown]
# **Exercise 0.2.5**
#
# Create an acronym: Starting from the list `["red", "green", "blue"]`, create the acronym "RGB" using a for loop.
#
# Hint: You may need to use a string method to properly format the acronym.

# %% [markdown]
# ## Conditionals
#
# Use `if` statements to control whether or not a block of code is executed.
#
# The structure is similar to a `for` statement:
# * First line opens with `if` and ends with a colon
# * Body containing one or more statements is indented (usually by 4 spaces)
#
# Consider that conditionals are often used inside loops.

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 3.0:
        print(m, 'is large')
# Out:
# 3.54 is large
# 9.22 is large

# %% [markdown]
# Use `else` to execute a block of code when an `if` condition is **not** true

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 3.0:
        print(m, 'is large')
    else:
        print(m, 'is small')
# Out:
# 3.54 is large
# 2.07 is small
# 9.22 is large
# 1.86 is small
# 1.71 is small

# %% [markdown]
# Use `elif` to specify additional tests

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 9.0:
        print(m, 'is HUGE')
    elif m > 3.0:
        print(m, 'is large')
    else:
        print(m, 'is small')
# Out:
# 3.54 is large
# 2.07 is small
# 9.22 is HUGE
# 1.86 is small
# 1.71 is small

# %% [markdown]
# * Conditions are tested once, in order.
# * Conditionals can be nested.

# %% [markdown]
# **Exercise 0.2.6**
#
# Fill in the blanks so that this program creates a new list containing zeroes where the original list’s values were negative and ones where the original list’s values were positive.

# %%
original = [-1.5, 0.2, 0.4, 0.0, -1.3, 0.4]
result = ____
for value in original:
    if ____:
        result.append(0)
    else:
        ____
print(result)

# %% [markdown]
# ---

# %% [markdown]
# ## **Copyright notice**
#
# ![cc-by.png](data:image/png;base64,...)
#
# This work by NVO Bioinformatika is licensed under CC BY 4.0.
#
# To view a copy of this license, visit:
#
# http://creativecommons.org/licenses/by/4.0/.
